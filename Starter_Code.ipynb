# %% [markdown]
# ## Preprocessing

# %%
# Importing our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# Importing and reading the charity_data.csv.
import pandas as pd 
application_df_full = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df_full.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Dropping the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df_full.drop(["EIN","NAME"],1)
application_df
# Out:
# <ipython-input-75-c3e5ec5ff78d>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   application_df = application_df_full.drop(["EIN","NAME"],1)
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# ...

# %%
# Determining the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Looking at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choosing a cutoff value and create a list of application types to be replaced
application_types_to_replace = ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']

# Replacing in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Checking to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Looking at CLASSIFICATION value counts for binning
classification_value_counts = application_df['CLASSIFICATION'].value_counts()
classification_value_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Looking at CLASSIFICATION value counts >1
classification_value_counts[classification_value_counts > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choosing a cutoff value and create a list of classifications to be replaced
classifications_to_replace = classification_value_counts.index.tolist()[5:]

# Replacing in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Checking to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()[:5]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# Name: CLASSIFICATION, dtype: int64

# %%
# Checking all categorical columns in the dataset
application_cat = application_df.dtypes[application_df.dtypes == "object"].index.tolist()
application_cat
# Out:
# ['APPLICATION_TYPE',
#  'AFFILIATION',
#  'CLASSIFICATION',
#  'USE_CASE',
#  'ORGANIZATION',
#  'INCOME_AMT',
#  'SPECIAL_CONSIDERATIONS']

# %%
# Converting categorical data to numeric with `pd.get_dummies`
dummy_data = pd.get_dummies(data=application_df, columns=['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 
                                             'USE_CASE', 'ORGANIZATION', 'SPECIAL_CONSIDERATIONS', 'INCOME_AMT', 'IS_SUCCESSFUL'])

# %%
# Checking the number of unique values in each column
dummy_data.nunique()
# Out:
# STATUS                             2
# ASK_AMT                         8747
# APPLICATION_TYPE_Other             2
# APPLICATION_TYPE_T10               2
# APPLICATION_TYPE_T19               2
# APPLICATION_TYPE_T3                2
# APPLICATION_TYPE_T4                2
# APPLICATION_TYPE_T5                2
# APPLICATION_TYPE_T6                2
# APPLICATION_TYPE_T7                2
# APPLICATION_TYPE_T8                2
# AFFILIATION_CompanySponsored       2
# AFFILIATION_Family/Parent          2
# AFFILIATION_Independent            2
# AFFILIATION_National               2
# AFFILIATION_Other                  2
# AFFILIATION_Regional               2
# CLASSIFICATION_C1000               2
# CLASSIFICATION_C1200               2
# CLASSIFICATION_C2000               2
# CLASSIFICATION_C2100               2
# CLASSIFICATION_C3000               2
# CLASSIFICATION_Other               2
# USE_CASE_CommunityServ             2
# USE_CASE_Heathcare                 2
# ...

# %%
# Splitting our preprocessed data into our features and target arrays
y = dummy_data["IS_SUCCESSFUL_1"].values
X = dummy_data.drop(["IS_SUCCESSFUL_1", "IS_SUCCESSFUL_0"],1).values

# Splitting the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# <ipython-input-85-3210947ecf00>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = dummy_data.drop(["IS_SUCCESSFUL_1", "IS_SUCCESSFUL_0"],1).values

# %%
# Creating a StandardScaler instances
scaler = StandardScaler()

# Fitting the StandardScaler
X_scaler = scaler.fit(X_train)

# Scaling the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Checking the dummy_data dataframe
dummy_data
# Out:
#        STATUS   ASK_AMT  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0           1      5000                       0                     1
# 1           1    108590                       0                     0
# 2           1      5000                       0                     0
# 3           1      6692                       0                     0
# 4           1    142590                       0                     0
# ...       ...       ...                     ...                   ...
# 34294       1      5000                       0                     0
# 34295       1      5000                       0                     0
# 34296       1      5000                       0                     0
# 34297       1      5000                       0                     0
# 34298       1  36500179                       0                     0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# ...

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Defining the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=43, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Checking the structure of the model
nn.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_36 (Dense)            (None, 80)                3520
#
#  dense_37 (Dense)            (None, 30)                2430
#
#  dense_38 (Dense)            (None, 1)                 31
#
# ...
# Total params: 5,981
# Trainable params: 5,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Training the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5715 - accuracy: 0.7214
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5554 - accuracy: 0.7296
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5532 - accuracy: 0.7320
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5517 - accuracy: 0.7311
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7323
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7332
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7342
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5473 - accuracy: 0.7340
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7345
# Epoch 10/100
# ...

# %%
# Evaluating the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5554 - accuracy: 0.7261 - 573ms/epoch - 2ms/step
# Loss: 0.555393636226654, Accuracy: 0.726064145565033

# %%
# Exporting our model to HDF5 file
nn.save('my_model.hdf5')

# %% [markdown]
# ## Optimising the model

# %%
# Trying to further create bins for the income amount column
income_value_counts = application_df['INCOME_AMT'].value_counts()
income_value_counts
# Out:
# 0                24388
# 25000-99999       3747
# 100000-499999     3374
# 1M-5M              955
# 1-9999             728
# 10000-24999        543
# 10M-50M            240
# 5M-10M             185
# 50M+               139
# Name: INCOME_AMT, dtype: int64

# %%
# Creating list of values to replace
income_value_to_replace = ['10M-50M', '5M-10M','50M+']

# Replacing in dataframe
for inc in income_value_to_replace:
    application_df['INCOME_AMT'] = application_df['INCOME_AMT'].replace(inc,"5M+")
    
# Checking to make sure binning was successful
application_df['INCOME_AMT'].value_counts()
# Out:
# 0                24388
# 25000-99999       3747
# 100000-499999     3374
# 1M-5M              955
# 1-9999             728
# 5M+                564
# 10000-24999        543
# Name: INCOME_AMT, dtype: int64

# %%
# Reading in the dataset again to include a new column
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")

# Making sure the bins are still present
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Trying to further create bins for the application types column
application_types_to_replace = ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17', 'T10']
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Making sure the bins are still present
for inc in income_value_to_replace:
    application_df['INCOME_AMT'] = application_df['INCOME_AMT'].replace(inc,"5M+")

# %%
# Converting categorical data to numeric with `pd.get_dummies`
dummy_data = pd.get_dummies(data=application_df, columns=['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION',
                                             'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'IS_SUCCESSFUL'])

# %%
# Splitting our preprocessed data into our features and target arrays
y = dummy_data["IS_SUCCESSFUL_1"].values
# Removing the Special considerations column to see if it enhances accuracy
X = dummy_data.drop(["IS_SUCCESSFUL_1", "IS_SUCCESSFUL_0", "SPECIAL_CONSIDERATIONS", "NAME"],1).values

# Splitting the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# <ipython-input-97-1eab62574f7c>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = dummy_data.drop(["IS_SUCCESSFUL_1", "IS_SUCCESSFUL_0", "SPECIAL_CONSIDERATIONS", "NAME"],1).values

# %%
# Creating a StandardScaler instances
scaler = StandardScaler()

# Fitting the StandardScaler
X_scaler = scaler.fit(X_train)

# Scaling the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Defining the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 120
hidden_nodes_layer3 = 100
hidden_nodes_layer4 = 50

nn2 = tf.keras.models.Sequential()

# First hidden layer
nn2.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=39, activation="relu")
)

# Second hidden layer
nn2.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer (changed activation function; added new layer)
nn2.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="tanh"))

# Fourth hidden layer (added new layer)
nn2.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="relu"))

# # Output layer
nn2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Checking the structure of the model
nn2.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_39 (Dense)            (None, 80)                3200
#
#  dense_40 (Dense)            (None, 120)               9720
#
#  dense_41 (Dense)            (None, 100)               12100
#
#  dense_42 (Dense)            (None, 50)                5050
#
#  dense_43 (Dense)            (None, 1)                 51
#
# ...
# Total params: 30,121
# Trainable params: 30,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
nn2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Training the model (lesser epochs)
fit_model = nn2.fit(X_train_scaled,y_train,epochs=80)
# Out:
# Epoch 1/80
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5657 - accuracy: 0.7218
# Epoch 2/80
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5531 - accuracy: 0.7318
# Epoch 3/80
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7329
# Epoch 4/80
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5476 - accuracy: 0.7341
# Epoch 5/80
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5457 - accuracy: 0.7357
# Epoch 6/80
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5434 - accuracy: 0.7359
# Epoch 7/80
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7367
# Epoch 8/80
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5405 - accuracy: 0.7376
# Epoch 9/80
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5396 - accuracy: 0.7383
# Epoch 10/80
# ...

# %%
# Evaluating the model using the test data
model_loss, model_accuracy = nn2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5694 - accuracy: 0.7318 - 501ms/epoch - 2ms/step
# Loss: 0.5693990588188171, Accuracy: 0.7317784428596497

# %%
# Exporting our model to HDF5 file
nn2.save('my_model2.hdf5')
